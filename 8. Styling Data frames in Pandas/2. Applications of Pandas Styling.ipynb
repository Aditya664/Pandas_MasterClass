# %% [markdown]
# https://towardsdatascience.com/10-examples-to-master-pandas-styler-408ea794e91

# %%
# importing libraries
import pandas as pd

# %%
# reading files
df = pd.read_csv('employee.csv')

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df.shape
# Out:
# (1470, 35)

# %%
grp_df = df.groupby(['Department','EducationField'])[['Age','DailyRate','MonthlyIncome']].agg('mean')

# %%
grp_df
# Out:
#                                                Age    DailyRate  MonthlyIncome
# Department             EducationField
# Human Resources        Human Resources   37.037037   675.259259    7241.148148
#                        Life Sciences     39.375000   753.062500    6914.062500
#                        Medical           39.846154   875.615385    6594.076923
#                        Other             34.666667  1005.000000    5016.666667
#                        Technical Degree  32.500000   667.000000    3081.250000
# Research & Development Life Sciences     36.997727   789.195455    6179.984091
#                        Medical           37.242424   825.730028    6539.223140
#                        Other             36.187500   763.359375    6278.687500
#                        Technical Degree  37.063830   846.202128    5760.819149
# Sales                  Life Sciences     37.186667   854.580000    7246.233333
# ...

# %%
# highlighting the max and min value
grp_df.style.highlight_max(color = 'red').highlight_min(color='lightgreen')
# Out:
# <style  type="text/css" >
# #T_ac0f05a6_d80d_11eb_8a73_dd5b3b087b5arow2_col0,#T_ac0f05a6_d80d_11eb_8a73_dd5b3b087b5arow3_col1,#T_ac0f05a6_d80d_11eb_8a73_dd5b3b087b5arow10_col2{
#             background-color:  red;
#         }#T_ac0f05a6_d80d_11eb_8a73_dd5b3b087b5arow4_col1,#T_ac0f05a6_d80d_11eb_8a73_dd5b3b087b5arow4_col2,#T_ac0f05a6_d80d_11eb_8a73_dd5b3b087b5arow12_col0{
#             background-color:  lightgreen;
# ...

# %%
pd.set_option('max_rows',1470)
df['DailyRate']
# Out:
# 0       1102
# 1        279
# 2       1373
# 3       1392
# 4        591
# 5       1005
# 6       1324
# 7       1358
# 8        216
# 9       1299
# 10       809
# 11       153
# 12       670
# 13      1346
# 14       103
# 15      1389
# 16       334
# 17      1123
# 18      1219
# 19       371
# 20       673
# 21      1218
# 22       419
# 23       391
# 24       699
# 25      1282
# 26      1125
# 27       691
# 28       477
# 29       705
# 30       924
# 31      1459
# 32       125
# 33       895
# 34       813
# 35      1273
# 36       869
# 37       890
# 38       852
# 39      1141
# 40       464
# 41      1240
# 42      1357
# 43       994
# 44       721
# 45      1360
# 46      1065
# 47       408
# 48      1211
# 49      1229
# 50       626
# 51      1434
# 52      1488
# 53      1097
# 54      1443
# 55       515
# 56       853
# 57      1142
# 58       655
# 59      1115
# 60       427
# 61       653
# 62       989
# 63      1435
# 64      1223
# 65       836
# ...

# %%
def above_thousand(x):
    color = 'red' if x>1000 else 'green'
    return 'color: %s' % color

# %%
df[['DailyRate']].style.applymap(above_thousand)
# Out:
# <style  type="text/css" >
# ...
