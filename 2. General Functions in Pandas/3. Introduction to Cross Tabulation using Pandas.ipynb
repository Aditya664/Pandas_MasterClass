# %% [markdown]
# ## Cross Tabulation
# Cross tabulation is a statistical tool that is used to analyze the categorical data.
# The crosstab() function of pyhton is used to compute a simple cross tabulation of two or more factors.

# %% [markdown]
# ### Example 1

# %%
import numpy as np
import pandas as pd
# creating arrays
a = np.array(["foo", "foo", "foo", "foo", "bar", "bar",
              "bar", "bar", "foo", "foo", "foo"], dtype=object)
b = np.array(["one", "one", "one", "two", "one", "one",
              "one", "two", "two", "two", "one"], dtype=object)
c = np.array(["dull", "dull", "shiny", "dull", "dull", "shiny",
              "shiny", "dull", "shiny", "shiny", "shiny"],
             dtype=object)

# %%
# performing crosstabulation
pd.crosstab(a, [b, c], rownames=['a'], colnames=['b', 'c'])
# Out:
# b    one        two
# c   dull shiny dull shiny
# a
# bar    1     2    1     0
# foo    2     2    1     2

# %% [markdown]
# ### Example 2

# %%
# reading dataset
df = pd.read_csv('employee.csv')
df.head(3)
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# 0  ...                         1            80                 0
# 1  ...                         4            80                 1
# 2  ...                         2            80                 0
#
#    TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# ...

# %%
# creating cross tab between department and education field columns
pd.crosstab(df['Department'], df['EducationField'])
# Out:
# EducationField          Human Resources  Life Sciences  Marketing  Medical  \
# Department
# Human Resources                      27             16          0       13
# Research & Development                0            440          0      363
# Sales                                 0            150        159       88
#
# EducationField          Other  Technical Degree
# Department
# Human Resources             3                 4
# Research & Development     64                94
# Sales                      15                34

# %%
# Out:
# EducationField                    Human Resources  Life Sciences  Marketing  \
# Department             Attrition
# Human Resources        No                      20             15          0
#                        Yes                      7              1          0
# Research & Development No                       0            381          0
#                        Yes                      0             59          0
# Sales                  No                       0            121        124
#                        Yes                      0             29         35
#
# EducationField                    Medical  Other  Technical Degree
# Department             Attrition
# Human Resources        No              11      3                 2
#                        Yes              2      0                 2
# Research & Development No             316     57                74
#                        Yes             47      7                20
# ...
