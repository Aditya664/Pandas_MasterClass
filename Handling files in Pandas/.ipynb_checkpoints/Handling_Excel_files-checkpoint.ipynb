# %%
import pandas as pd

# %%
# read excel
df = pd.read_excel(r'C:\Users\add\Documents\GitHub\Pandas_MasterClass\datasets\Annual_attendance.xlsx')
df
# Out:
#      Starting Year  Rank       Team  Home: Total Games  \
# 0             2015     1      Bulls                 41
# 1             2015     2  Cavaliers                 41
# 2             2015     3  Mavericks                 41
# 3             2015     4    Raptors                 41
# 4             2015     5  NY Knicks                 41
# ..             ...   ...        ...                ...
# 471           2000    25   Warriors                 41
# 472           2000    26       Nets                 41
# 473           2000    27  Grizzlies                 41
# 474           2000    28      Hawks                 41
# 475           2000    29    Rockets                 41
#
#      Home: Total Attendance  Home: Avg Attendance Home: % Capactiy  \
# 0                    894659                 21820            104.3
# 1                    843042                 20562              100
# 2                    825901                 20143            104.9
# ...

# %%
# head  function
df.head()
# Out:
#    Starting Year  Rank       Team  Home: Total Games  Home: Total Attendance  \
# 0           2015     1      Bulls                 41                  894659
# 1           2015     2  Cavaliers                 41                  843042
# 2           2015     3  Mavericks                 41                  825901
# 3           2015     4    Raptors                 41                  812863
# 4           2015     5  NY Knicks                 41                  812292
#
#    Home: Avg Attendance Home: % Capactiy  Away: Total Games  \
# 0                 21820            104.3                 41
# 1                 20562              100                 41
# 2                 20143            104.9                 41
# 3                 19825            100.1                 41
# 4                 19812              100                 41
#
#    Away: Total Attendance Away: Avg Attendance  Away: % Capactiy
# 0                   18156                 94.5                82
# ...
